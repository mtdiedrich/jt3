# %%
# %load_ext sql

# Connect SQLMagic directly to the project DuckDB file.
# %sql duckdb:///f:/Project/games/jt3/data/jt3.duckdb

# %config SqlMagic.autopolars = True
# Out:
# The 'toml' package isn't installed. To load settings from pyproject.toml or ~/.jupysql/config, install with: pip install toml
# Connecting to 'duckdb:///f:/Project/games/jt3/data/jt3.duckdb'

# %%
# %sql SELECT table_name FROM information_schema.tables WHERE table_schema = 'main'
# Out:
# Running query in 'duckdb:///f:/Project/games/jt3/data/jt3.duckdb'
# shape: (10, 1)
# ┌────────────────────────────────┐
# │ table_name                     │
# │ ---                            │
# │ str                            │
# ╞════════════════════════════════╡
# │ categories                     │
# │ clues                          │
# │ clue_embeddings                │
# │ contestants                    │
# │ contextual_response_embeddings │
# │ embeddings                     │
# │ episodes                       │
# │ prompted_response_embeddings   │
# │ response_embeddings            │
# │ rounds                         │
# └────────────────────────────────┘
